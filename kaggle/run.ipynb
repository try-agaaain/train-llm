# %% [markdown]
# ## 评估模型——生成数据集

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
MODELSCOPE_TOKEN = user_secrets.get_secret("MODELSCOPE_TOKEN")

# !git clone https://github.com/try-agaaain/train-llm.git

# !pip install uv
# !cd train-llm && uv sync
# !cd train-llm && make evaluate
# !cd train-llm && MODELSCOPE_TOKEN=$MODELSCOPE_TOKEN make push-model

# %% [markdown]
# ## 训练模型

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
MODELSCOPE_TOKEN = user_secrets.get_secret("MODELSCOPE_TOKEN")

# !git clone https://github.com/try-agaaain/train-llm.git

# !pip install uv
# !cd train-llm && uv sync
# !cd train-llm && make train
# !cd train-llm && MODELSCOPE_TOKEN=$MODELSCOPE_TOKEN make push-model
